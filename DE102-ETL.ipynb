# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#extract menjadi data frame
df = pd.read_csv('Salary Prediction.csv')
df.head(1)
# Out:
#    FIRST NAME    LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0      TOMASA        ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1       ANNIE          NaN   F         NaN   01-07-2016   Associate   NaN
# 2       OLIVE         ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3      CHERRY      AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4        LEON   ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
# ..        ...          ...  ..         ...          ...         ...   ...
# 95     JOSEFA  APPLEWHAITE   F   5-19-2014   01-07-2016     Analyst  22.0
# 96      OSCAR       ABLING   M  08-01-2013   01-07-2016     Analyst  22.0
# 97  ROOSEVELT         ADES   M  02-12-2014   01-07-2016     Analyst  24.0
# 98     MARVIN        ABELS   M   9-15-2014   01-07-2016     Analyst  22.0
# 99   MARCELLA          AMY   F   5-17-2014   01-07-2016     Analyst  24.0
#
#     SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# ...

# %%
#create engine connection to postgres
engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

# %%
#Load to database postgres sql
df.to_sql('salary_prediction',con=engine, if_exists='append', index=False)
