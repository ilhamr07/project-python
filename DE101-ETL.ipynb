# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#connection

#engine = create_engine('postgresql://username:password@localhost:5432/mydatabase')
engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

# %%
df = pd.read_csv('customer_data.csv')
df.head()

# %%
#transform
df['registered_date'] = pd.to_datetime(df['registered_date']).dt.strftime('%Y-%m-%d %H:%M:%S')
df['dob'] = pd.to_datetime(df['dob']).dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df.head()

# %%
#Load
df.to_sql('customer_data',con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# d:\Python\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1889                 if not evt_handled:
# -> 1890                     self.dialect.do_executemany(
#    1891                         cursor, statement, parameters, context
#
# d:\Python\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     981             xtras = self._psycopg2_extras()
# --> 982             context._psycopg2_fetched_rows = xtras.execute_values(
#     983                 cursor,
#
# d:\Python\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1298         parts[-1:] = post
# -> 1299         cur.execute(b''.join(parts))
#    1300         if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "customer_data_pkey"
# DETAIL:  Key (unique_code)=(1313b921-f297-4a2d-a21f-86ae59979411) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-43-f6b76a6b0232> in <module>
#       1 #Load
# ----> 2 df.to_sql('customer_data',con=engine, if_exists='append', index=False)
#
# d:\Python\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# d:\Python\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# d:\Python\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# d:\Python\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# d:\Python\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# d:\Python\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# d:\Python\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1383             )
#    1384         else:
# -> 1385             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1386
#    1387     def _execute_function(self, func, multiparams, params, execution_options):
#
# d:\Python\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     332     ):
#     333         if _force or self.supports_execution:
# --> 334             return connection._execute_clauseelement(
#     335                 self, multiparams, params, execution_options
#     336             )
#
# d:\Python\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1575             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1576         )
# -> 1577         ret = self._execute_context(
#    1578             dialect,
#    1579             dialect.execution_ctx_cls._init_compiled,
#
# d:\Python\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1951
#    1952         except BaseException as e:
# -> 1953             self._handle_dbapi_exception(
#    1954                 e, statement, parameters, cursor, context
#    1955             )
#
# d:\Python\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2132                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2133             elif should_wrap:
# -> 2134                 util.raise_(
#    2135                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2136                 )
#
# d:\Python\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# d:\Python\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1888                             break
#    1889                 if not evt_handled:
# -> 1890                     self.dialect.do_executemany(
#    1891                         cursor, statement, parameters, context
#    1892                     )
#
# d:\Python\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     980                 kwargs = {}
#     981             xtras = self._psycopg2_extras()
# --> 982             context._psycopg2_fetched_rows = xtras.execute_values(
#     983                 cursor,
#     984                 statement,
#
# d:\Python\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1297             parts.append(b',')
#    1298         parts[-1:] = post
# -> 1299         cur.execute(b''.join(parts))
#    1300         if fetch:
#    1301             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "customer_data_pkey"
# DETAIL:  Key (unique_code)=(1313b921-f297-4a2d-a21f-86ae59979411) already exists.
#
# [SQL: INSERT INTO customer_data (unique_code, first_name, last_name, gender, email, username, dob, registered_date, phone, picture, post_code, address) VALUES (%(unique_code)s, %(first_name)s, %(last_name)s, %(gender)s, %(email)s, %(username)s, %(dob)s, %(registered_date)s, %(phone)s, %(picture)s, %(post_code)s, %(address)s)]
# [parameters: ({'unique_code': '1313b921-f297-4a2d-a21f-86ae59979411', 'first_name': 'Batur', 'last_name': 'Bolatlı', 'gender': 'male', 'email': 'batur.bolatli@example.com', 'username': 'bigzebra592', 'dob': '1966-11-12 12:32:38', 'registered_date': '2015-02-14 03:05:44', 'phone': '(366)-463-1187', 'picture': 'https://randomuser.me/api/portraits/med/men/88.jpg', 'post_code': '16889', 'address': '1912 Maçka Cd, Muş, Burdur, Turkey'}, {'unique_code': '5706445d-63fd-4484-bed8-d3e0422dcae1', 'first_name': 'Grigorije', 'last_name': 'Pantelić', 'gender': 'male', 'email': 'grigorije.pantelic@example.com', 'username': 'ticklishleopard883', 'dob': '1955-07-27 13:55:57', 'registered_date': '2020-04-06 05:41:38', 'phone': '011-1886-812', 'picture': 'https://randomuser.me/api/portraits/med/men/1.jpg', 'post_code': '84016', 'address': '3863 Gorička, Irig, Moravica, Serbia'}, {'unique_code': '98f25e78-2dcb-40bc-ab3d-68f3d84d4945', 'first_name': 'Luz', 'last_name': 'Martínez', 'gender': 'female', 'email': 'luz.martinez@example.com', 'username': 'ticklishgorilla596', 'dob': '2000-06-17 14:16:12', 'registered_date': '2006-01-08 09:30:16', 'phone': '952-825-234', 'picture': 'https://randomuser.me/api/portraits/med/women/82.jpg', 'post_code': '23479', 'address': '3374 Paseo de Extremadura, Lorca, Comunidad de Madrid, Spain'}, {'unique_code': '0fe89191-5fba-40ce-af8b-643afc45e33a', 'first_name': 'Ayşe', 'last_name': 'Özdoğan', 'gender': 'female', 'email': 'ayse.ozdogan@example.com', 'username': 'redgorilla368', 'dob': '1956-02-22 10:26:43', 'registered_date': '2015-07-05 11:11:38', 'phone': '(723)-822-6923', 'picture': 'https://randomuser.me/api/portraits/med/women/94.jpg', 'post_code': '38639', 'address': '5736 Anafartalar Cd, Nevşehir, Artvin, Turkey'}, {'unique_code': '6e540063-883b-42a0-8b39-36df1811ee42', 'first_name': 'Fatma', 'last_name': 'Çağıran', 'gender': 'female', 'email': 'fatma.cagiran@example.com', 'username': 'orangeduck449', 'dob': '1993-04-05 02:27:18', 'registered_date': '2021-03-11 19:33:23', 'phone': '(500)-892-1440', 'picture': 'https://randomuser.me/api/portraits/med/women/8.jpg', 'post_code': '57317', 'address': '157 Atatürk Sk, Hatay, Çorum, Turkey'}, {'unique_code': 'b9d05d49-bf0f-494c-b77f-8643c6daae9d', 'first_name': 'Nora', 'last_name': 'Mendoza', 'gender': 'female', 'email': 'nora.mendoza@example.com', 'username': 'yellowlion485', 'dob': '1960-06-28 14:26:21', 'registered_date': '2007-03-22 06:50:49', 'phone': '04-8669-5803', 'picture': 'https://randomuser.me/api/portraits/med/women/75.jpg', 'post_code': '4268', 'address': '3200 W 6th St, Coffs Harbour, South Australia, Australia'}, {'unique_code': '2b186e74-b79b-4ed8-b1ec-89b7225a6b64', 'first_name': 'Arturo', 'last_name': 'Peña', 'gender': 'male', 'email': 'arturo.pena@example.com', 'username': 'whitepeacock570', 'dob': '1977-02-18 08:19:48', 'registered_date': '2017-02-12 23:34:16', 'phone': '911-364-732', 'picture': 'https://randomuser.me/api/portraits/med/men/49.jpg', 'post_code': '34082', 'address': '5583 Calle de Atocha, Valencia, Comunidad de Madrid, Spain'}, {'unique_code': '65c34a9b-4d3b-4ef6-a349-70534f9a58a4', 'first_name': 'Ishani', 'last_name': 'Jutte', 'gender': 'female', 'email': 'ishani.jutte@example.com', 'username': 'organicladybug125', 'dob': '1964-03-27 18:03:53', 'registered_date': '2006-09-27 22:38:39', 'phone': '(096) 6356242', 'picture': 'https://randomuser.me/api/portraits/med/women/26.jpg', 'post_code': '1494 YQ', 'address': '2778 Havikdijk, Nieuwerbrug aan den Rijn, Overijssel, Netherlands'}  ... displaying 10 of 100 total bound parameter sets ...  {'unique_code': 'ca1ac8c2-058f-4123-9649-e54a949e1dc2', 'first_name': 'Rebecca', 'last_name': 'Parker', 'gender': 'female', 'email': 'rebecca.parker@example.com', 'username': 'organicswan426', 'dob': '1959-05-19 02:23:58', 'registered_date': '2015-10-28 03:27:56', 'phone': '02-5918-7121', 'picture': 'https://randomuser.me/api/portraits/med/women/56.jpg', 'post_code': '5479', 'address': '7755 Mill ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
